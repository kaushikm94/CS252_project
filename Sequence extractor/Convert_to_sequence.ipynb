# %%
import re
#with open('C:/Users/Karthik/Desktop/297/js_libraries/final extracted/tracker_base.txt', 'r') as myfile:
with open('C:/Users/Karthik/Desktop/benign/AddressBookArguments','r') as myfile:
    file1=myfile.readlines()
print(len(file1))
opcode1=[]
i=0
nocount=0;
mydict={"aaload":1,"aload_0":2,"invokespecial":3,"iload_3":4,"putfield":5,"aload_1":6,"aload_2":7,
       "tableswitch":8,"return":9,"iconst_0":10,"new":11,"dup":12,"invokestatic":13,"aconst_null":14,
        "invokevirtual":15,"areturn":16,"ifne":17,"aload":18,"getfield":19,"ldc":20,"sipush":21,"bipush":22,
        "putstatic":23,"ireturn":24,"aload_3":25,"iload_1":26,"iconst_4":27,"iconst_1":28,"iconst_3":29,"ldc_w":33
       }

temp=0;
while(i<len(file1)):
    x = file1[i].strip()
    #print(x);
    if(x!=""):
        if(x[0].isdigit()):
            temp=temp+1;
            y = x.split(":")[1].strip()
            #parsed = re.sub('(\\s[0-9]+$)','\1',y)
            parsed= re.sub('#[0-9$]+', '', y).strip()
    #         print(parsed);
            if(parsed in list(mydict.keys())):
                opcode1.append(mydict[parsed])
            else:
                #print(parsed)
                nocount = nocount+1;
        i=i+1;
    else:
        i=i+1;
# print(temp)
print(len(opcode1))
print(opcode1) 
print("Missing",nocount);
# Out:
# 247
# 98
# [2, 2, 4, 2, 7, 6, 4, 9, 9, 9, 9, 2, 2, 10, 9, 12, 2, 9, 2, 6, 7, 12, 14, 16, 6, 2, 6, 7, 25, 16, 2, 6, 7, 25, 2, 16, 16, 16, 16, 16, 10, 24, 2, 16, 16, 16, 16, 16, 2, 10, 24, 28, 24, 10, 24, 10, 24, 10, 24, 2, 28, 24, 28, 24, 10, 24, 10, 24, 10, 24, 2, 16, 16, 14, 16, 14, 16, 14, 16, 2, 10, 16, 16, 16, 16, 16, 2, 10, 24, 10, 24, 10, 24, 10, 24, 10, 24, 9]
# Missing 93

# %%
Y= [2, 3, 2, 10, 5, 9, 11, 12, 3, 2, 13, 9, 2, 6, 7, 12, 14, 15, 16, 6, 13, 2, 6, 7, 25, 13, 16, 2, 6, 7, 25, 13, 16, 10, 24, 20, 16, 10, 24, 10, 24, 14, 16, 11, 12, 20, 3, 12, 20, 15, 12, 20, 15, 15, 10, 20, 15, 16, 10, 24, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 27, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 29, 13, 23, 13, 23, 13, 23, 13, 23, 13, 23, 9]

print(len(Y))
l = 500-len(Y)
X= []
for i in range(l):
    X.append(45);
print(X)

Z = Y + X;
print(Z)
# Out:
# 171
# ...
