# %%
from pathlib import Path
import matplotlib.pyplot as plt
contents = Path(r"C:\Users\Karthik\Desktop\All documents\SEM01\aplp\Project\CS252_project\Output files\sampleJS_finalconverted.txt").read_text();

# %%
# Read and parse both file contents

with open('Output files\sampleJS_opcode.java', 'r') as myfile:
    #input file as an array
    file1=myfile.readlines()
    #input file character by character
    #file1=myfile.read()
with open('Output files\sampleJS_opcode.java', 'r') as myfile:    
#with open('Output files\Obf_sample_opcodes.java', 'r') as myfile:
    file2=myfile.readlines()

opcode1=[]
opcode2=[]
i=0;

# Parse input file.
# Select rows that begin with a number and ignore the rest
while(i<len(file1)):
    # Remove leading whitespaces
    x = file1[i].strip()
    # Check if it starts with a digit
    if(x[0].isdigit()):
        # Split based on delimiter ':' to extract actual op code
        y = x.split(":")
        opcode1.append(y[1])
        #if(y[1].isdigit()):
            #opcode.append(y[1])
    i=i+1;

#print(*opcode1, sep = "\n") 
n=len(opcode1)
#print(n)

j=0
print("Second file contents",len(file2));
while(j<len(file2)):
    a = file2[j].strip()
    if(a[0].isdigit()):
        b = a.split(":")
        #print(b[1])
        #if(b[1].isdigit()):     Check if the split string is a digit or not
        opcode2.append(b[1])
    j=j+1;

print(*opcode2, sep = "\n")
m=len(opcode2)
print(m)
# Out:
# Second file contents 185
#  aload_0
#  invokespecial #11                 // Method org/mozilla/javascript/NativeFunction."<init>"
#  aload_0
#  iload_3
#  putfield      #13                 // Field _id
#  aload_0
#  aload_2
#  aload_1
#  invokespecial #17                 // Method _i1
#  return
#  aload_0
#  invokespecial #11                 // Method org/mozilla/javascript/NativeFunction."<init>"
#  aload_0
#  iconst_0
#  putfield      #13                 // Field _id
#  return
#  new           #2                  // class sampleJS
#  dup
#  invokespecial #24                 // Method "<init>"
#  aload_0
#  invokestatic  #29                 // Method org/mozilla/javascript/optimizer/OptRuntime.main
#  return
#  aload_0
#  aload_1
#  aload_2
#  dup
#  aconst_null
#  invokevirtual #35                 // Method call
#  areturn
#  aload_1
#  invokestatic  #41                 // Method org/mozilla/javascript/ScriptRuntime.hasTopCall
#  ifne          17
#  aload_0
#  aload_1
#  aload_2
#  aload_3
#  aload         4
#  invokestatic  #45                 // Method org/mozilla/javascript/ScriptRuntime.doTopCall
#  areturn
#  aload_0
#  aload_1
#  aload_2
#  aload_3
#  aload         4
#  aload_0
#  getfield      #13                 // Field _id
#  tableswitch   { // 1 to 1
#  48
#  invokestatic  #49                 // Method _c_script_0
#  areturn
#  invokestatic  #52                 // Method _c_sum_1
#  areturn
#  iconst_0
#  ireturn
#  aload_0
#  getfield      #13                 // Field _id
#  tableswitch   { // 1 to 1
#  27
#  ldc           #58                 // String
#  areturn
#  ldc           #60                 // String sum
#  areturn
#  aload_0
#  getfield      #13                 // Field _id
#  tableswitch   { // 1 to 1
#  26
#  iconst_0
#  ireturn
#  iconst_0
#  ireturn
#  aload_0
#  getfield      #13                 // Field _id
#  tableswitch   { // 1 to 1
#  26
#  iconst_4
#  ireturn
#  iconst_1
#  ireturn
#  aload_0
#  getfield      #13                 // Field _id
#  tableswitch   { // 1 to 1
#  64
#  iload_1
#  tableswitch   { // 1 to 3
#  55
#  58
#  61
#  ldc           #66                 // String x
#  areturn
#  ldc           #68                 // String y
#  areturn
#  ldc           #70                 // String z
#  areturn
#  ldc           #60                 // String sum
#  areturn
#  ldc           #70                 // String z
#  areturn
#  ldc           #73
#  aload_0
#  getfield      #13                 // Field _id
#  tableswitch   { // 1 to 1
#  31
#  iconst_0
#  bipush        81
#  invokevirtual #79                 // Method java/lang/String.substring
#  areturn
#  bipush        35
#  bipush        70
#  invokevirtual #79                 // Method java/lang/String.substring
#  areturn
#  aload_0
#  getfield      #13                 // Field _id
#  tableswitch   { // 1 to 1
#  60
#  iload_1
#  tableswitch   { // 1 to 3
#  54
#  56
#  58
#  iconst_0
#  ireturn
#  iconst_0
#  ireturn
#  iconst_0
#  ireturn
#  iconst_0
#  ireturn
#  iconst_0
#  ireturn
#  bipush        10
#  invokestatic  #140                // Method java/lang/Integer.valueOf
#  putstatic     #105                // Field _k0
#  bipush        20
#  invokestatic  #140                // Method java/lang/Integer.valueOf
#  putstatic     #112                // Field _k1
#  bipush        30
#  invokestatic  #140                // Method java/lang/Integer.valueOf
#  putstatic     #123                // Field _k2
#  return
# 139

# %%
# Plot the similarity graph

xaxis=[]
yaxis=[]

x=0
y=0
i=0

#Check for sequential matches
for i in range(len(opcode1)-3):
    sub1,sub2=[],[]
    sub1.append(opcode1[i])
    sub1.append(opcode1[i+1])
    sub1.append(opcode1[i+2])
    sub2.append(opcode2[i])
    sub2.append(opcode2[i+1])
    sub2.append(opcode2[i+2])
    #print(sub1,'\n',sub2)
    result =  all(elem in sub1  for elem in sub2)
    #print(result)
    if(result== True):
        xaxis.append(i)
        yaxis.append(i)

plt.plot(n-1,m-1,xaxis,yaxis)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Similarity graph 1') 
plt.show()
        
#Check for all matches across both lists

for i in range(len(opcode1)-3):
    for j in range(len(opcode2)-3):
        sub1,sub2=[],[]
        sub1.append(opcode1[i])
        sub1.append(opcode1[i+1])
        sub1.append(opcode1[i+2])
        sub2.append(opcode2[j])
        sub2.append(opcode2[j+1])
        sub2.append(opcode2[j+2])
        #print(sub1,'\n',sub2)
        result =  all(elem in sub1  for elem in sub2)
        #print(result)
        if(result== True):
            xaxis.append(i)
            yaxis.append(j)
# print(len(xaxis),len(yaxis))
# print(xaxis)
# print(yaxis)

#Give x values and y values. x=[], y=[].
plt.plot(n-1,m-1,xaxis,yaxis)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Similarity graph 2') 
plt.show()
